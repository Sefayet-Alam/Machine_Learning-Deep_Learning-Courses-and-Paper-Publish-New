# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Obtaining dependency information for pandas-profiling from https://files.pythonhosted.org/packages/57/b7/e13216265ae3135ecda13e966aad9ce04b7e7b3e2d87d056b032fc9f457c/pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: joblib~=1.1.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (2.3.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (2.12.5)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (3.1.6)
# Requirement already satisfied: markupsafe~=2.1.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (2.1.5)
# Collecting visions[type_image_path]==0.7.4 (from pandas-profiling)
#   Obtaining dependency information for visions[type_image_path]==0.7.4 from https://files.pythonhosted.org/packages/66/00/166b2beb8046f06b77a2bf2c1dafeb52eff608f7dd420c767d5f3ce36ef5/visions-0.7.4-py3-none-any.whl.metadata
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (2.3.5)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (4.67.3)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas-profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.6.1)
# Requirement already satisfied: imagehash in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.2)
# Requirement already satisfied: Pillow in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Requirement already satisfied: PyWavelets in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.9.0)
# Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Installing collected packages: visions, pandas-profiling
#   Attempting uninstall: visions
#     Found existing installation: visions 0.8.1
#     Uninstalling visions-0.8.1:
#       Successfully uninstalled visions-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.18.1 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.
# Successfully installed pandas-profiling-3.2.0 visions-0.7.4
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas_profiling/__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas_profiling/controller/pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)     15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas_profiling/profile_report.py:13
#      10 from tqdm.auto import tqdm
#      11 from visions import VisionsTypeset
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.alerts import AlertType
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pandas_profiling/config.py:5
#       2 from enum import Enum
#       3 from typing import Any, Dict, List, Optional
# ----> 5 from pydantic import BaseModel, BaseSettings, Field
#       8 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#       9     """
#      10     Recursive merge dictionaries.
#      11
#    (...)     14     :return: Merged dictionary
#      15     """
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pydantic/__init__.py:437, in __getattr__(attr_name)
#     435 dynamic_attr = _dynamic_imports.get(attr_name)
#     436 if dynamic_attr is None:
# --> 437     return _getattr_migration(attr_name)
#     439 package, module_name = dynamic_attr
#     441 if module_name == '__module__':
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/pydantic/_migration.py:304, in getattr_migration.<locals>.wrapper(name)
#     302     return import_string(REDIRECT_TO_V1[import_path])
#     303 if import_path == 'pydantic:BaseSettings':
# --> 304     raise PydanticImportError(
#     305         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     306         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     307         'for more details.'
#     308     )
#     309 if import_path in REMOVED_IN_V2:
#     310     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.12/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.12/u/import-error
