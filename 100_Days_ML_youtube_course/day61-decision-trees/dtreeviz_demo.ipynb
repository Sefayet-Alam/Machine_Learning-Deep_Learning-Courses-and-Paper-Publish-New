# %%
# %pip install dtreeviz
# %pip install graphviz
# %pip install tree
# Out:
# Requirement already satisfied: dtreeviz in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (2.3.2)
# Requirement already satisfied: graphviz>=0.9 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from dtreeviz) (0.21)
# Requirement already satisfied: pandas in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from dtreeviz) (2.3.3)
# Requirement already satisfied: numpy in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from dtreeviz) (2.3.5)
# Requirement already satisfied: scikit-learn in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from dtreeviz) (1.8.0)
# Requirement already satisfied: matplotlib in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from dtreeviz) (3.10.0)
# Requirement already satisfied: colour in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn->dtreeviz) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: graphviz in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (0.21)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tree in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (0.2.4)
# Requirement already satisfied: Pillow in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from tree) (11.3.0)
# Requirement already satisfied: svgwrite in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from tree) (1.4.3)
# Requirement already satisfied: setuptools in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from tree) (65.5.0)
# Requirement already satisfied: click in /Users/sefayet/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from tree) (8.2.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
from sklearn import tree

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # 1. Classification

# %%
from sklearn.tree import export_graphviz

# %%
from dtreeviz import model

viz_model = model(
    clas,
    X_train=X_train,
    y_train=y_train,
    feature_names=iris.feature_names,
    target_name="species",
    class_names=["setosa", "versicolor", "virginica"]
)

viz = viz_model.view()
viz

# %% [markdown]
# # 2. Regression

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from dtreeviz import model

regr = tree.DecisionTreeRegressor(max_depth=1, random_state=42)

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)

X = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]

feature_names = [
    "CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
    "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT"
]

regr.fit(X, y)

viz_model = model(
    regr,
    X_train=X,
    y_train=y,
    feature_names=feature_names,
    target_name="price"
)

viz = viz_model.view(scale=2)
viz

# %% [markdown]
# # 3. Horizontal Decision Tree

# %%
from dtreeviz import model

viz_model = model(
    clas,
    X_train=X_train,
    y_train=y_train,
    feature_names=iris.feature_names,
    target_name="price",
    class_names=["setosa", "versicolor", "virginica"]
)

viz = viz_model.view(scale=1.5, orientation="LR")
viz

# %% [markdown]
# # 4. Show prediction path

# %%
from sklearn import tree
from sklearn.datasets import load_iris
import numpy as np
from dtreeviz import model

clas = tree.DecisionTreeClassifier(random_state=42)
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

x = iris.data[np.random.randint(0, len(iris.data)), :]

viz_model = model(
    clas,
    X_train=X_train,
    y_train=y_train,
    feature_names=iris.feature_names,
    target_name="species",
    class_names=["setosa", "versicolor", "virginica"]
)

viz = viz_model.view(x=x)
viz

# %%
X
# Out:
# array([5.5, 2.3, 4. , 1.3])

# %% [markdown]
# # 5. Show node number

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               show_node_labels=True)
viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 6. Without Any graphs

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               fancy=False)
viz

# %% [markdown]
# # 7. Show just prediction path, nothing else

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X,
               show_just_path=True)
viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 8. Prediction Path in Plain english

# %%
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="plain_english"))
# Out:
# sepal length (cm) < 5.95
# petal length (cm) < 4.85
# 1.75 <= petal width (cm)

# %% [markdown]
# # 9. Feature Importance

# %%
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="sklearn_default"))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # 10. Univariate Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

df_cars = pd.read_csv("cars.csv")
X, y = df_cars[['WGT']], df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

fig = plt.figure()
ax = fig.gca()
rtreeviz_univar(dt, X, y, 'WGT', 'MPG', ax=ax)
plt.show()

# %% [markdown]
# # 11. 3-D Regression

# %%
df_cars = pd.read_csv("cars.csv")

df_cars
# Out:
#       MPG  CYL    ENG   WGT
# 0    18.0    8  307.0  3504
# 1    15.0    8  350.0  3693
# 2    18.0    8  318.0  3436
# 3    16.0    8  304.0  3433
# 4    17.0    8  302.0  3449
# ..    ...  ...    ...   ...
# 387  27.0    4  140.0  2790
# 388  44.0    4   97.0  2130
# 389  32.0    4  135.0  2295
# 390  28.0    4  120.0  2625
# 391  31.0    4  119.0  2720
#
# [392 rows x 4 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *


X = df_cars[['WGT','ENG']]
y = df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

figsize = (6,5)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection='3d')

t = rtreeviz_bivar_3D(dt,
                      X, y,
                      feature_names=['Vehicle Weight', 'Horse Power'],
                      target_name='MPG',
                      fontsize=14,
                      elev=20,
                      azim=25,
                      dist=8.2,
                      show={'splits','title'},
                      ax=ax)
plt.show()
