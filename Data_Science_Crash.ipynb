# %% [markdown]
# <a href="https://colab.research.google.com/github/Sefayet-Alam/Machine_Learning-Deep_Learning-Courses-and-Paper-Publish/blob/main/Data_Science_Crash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Started Using colab")
# Out:
# HEllo
